# %% [markdown]
# # Development Notebook for Mimir
# * POC looking at querying firebase and implementing a radar mode.
# * Looking to successfully query Firebase via the API.
# * Think about how the data coming in should be formatted.
# * How should the results be displayed?

# %% [markdown]
# ## Radar Mode Flow
# 1. When performing a Radar Mode request - let's say for instance a user is on the app and say I request a Radar Mode report for sensor 1.
# 2. This now fires off a GET request to our API.
# 3. From the request we should receive a UNIQUE DEVICE ID.
# 4. Can now query the sensor data table in order to get the latest sensor reading.
# 5. Request should also include a plant ID - used to look up in the plant data table and retrieve data
# 6. Peform the analysis and return data to the user

# %% [markdown]
# * _Data is currently in the wrong form_ :
#
# userInfo
# deviceId
# "P4006"
# ipAddress
# "62.203.6.17"
# macAddress
# "24:6F:28:B1:DC:D8"
# userId
# "Desk Top"
# userName
# "Lloyd"
# version
# "P2004.11C"
#
# * We do have a deviceId - not sure if this is unique - so will use this for now.

# %% [markdown]
# ## 1. Obtain Correct Sensor Data

# %%
# Example - get all readings for a certain user/ device
import requests
import json
from pprint import pprint

# Receive a Radar Mode Request from a User
# They will have to select a device and a plant that they want a reading for
deviceId = "P4006" # should be unique
userId = "xyz" # would ordinarily get a user ID as well

# They would say which species they are performing the analysis for
plant_species = "aloe vera" # would normally be a plant ID

# Build up a URL for request
base_url = "https://firestore.googleapis.com/v1/projects/mimirhome-app/databases/(default)/documents/"

# Get the relevant sensor data
sensor_data = requests.get(base_url + "sensorData/").text

# Obtain in json format
sensor_json = json.loads(sensor_data)

# Obtain all entries that match the deviceId
device_data = [s for s in sensor_json['documents'] if s['fields']['userInfo']['mapValue']['fields']['deviceId']['stringValue'] == deviceId]

# %%
sensor_json
# Out:
# {'documents': [{'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/00ebE6UhN4wVIJeMU8Az',
#    'fields': {'userInfo': {'mapValue': {'fields': {'userId': {'stringValue': 'Desk Top'},
#        'version': {'stringValue': 'P2004.11C'},
#        'userName': {'stringValue': 'Lloyd'},
#        'ipAddress': {'stringValue': '62.203.6.17'},
#        'macAddress': {'stringValue': '24:6F:28:B1:DC:D8'},
#        'deviceId': {'stringValue': 'P4006'}}}},
#     'data': {'mapValue': {'fields': {'UVA(VEML6075)': {'doubleValue': 67.67},
#        'UVIndex(VEML6075)': {'doubleValue': 0.057497},
#        'eCO2(CCS811)': {'integerValue': '1533'},
#        'UVB(VEML6075)': {'doubleValue': 31.85},
#        'Temperature(SHT31_H)': {'doubleValue': 24.66},
#        'Temperature(SHT31_L)': {'doubleValue': 24.82},
#        'Humidity(SHT31_H)': {'doubleValue': 24.85},
#        'Luminance(VEML6030)': {'integerValue': '1377'},
#        'Temperature(bmp280)': {'doubleValue': 26.12},
#        'Altitude(BMP280)': {'doubleValue': 969.3142},
#        'Humidity(SHT31_L)': {'doubleValue': 24.97},
#        'Pressure(BMP280)': {'doubleValue': 969.3142},
#        'VOC(CCS811)': {'integerValue': '194'},
#        'Bearing(Compass)': {'integerValue': '135'}}}},
#     'timestamp': {'integerValue': '1590931847726'},
#     'status': {'mapValue': {'fields': {'WiFi_Signal': {'integerValue': '-59'},
#        'Battery_Status': {'integerValue': '0'},
#        'Sensors_Status': {'integerValue': '1'},
#        'Date': {'stringValue': '2020-05-31'},
#        'MicroSD_Status': {'integerValue': '1'},
#        'Server_Status': {'integerValue': '1'},
#        'Battery_Percent': {'integerValue': '-6'},
#        'WiFI_Status': {'integerValue': '1'},
#        'Time': {'stringValue': '15:30:44'}}}}},
#    'createTime': '2020-05-31T13:30:47.840863Z',
#    'updateTime': '2020-05-31T13:30:47.840863Z'},
#   {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/00fRG1k0N2xzPcjvU2Ez',
#    'fields': {'data': {'mapValue': {'fields': {'Temperature(SHT31_L)': {'doubleValue': 26.25},
#        'UVB(VEML6075)': {'doubleValue': -242479.5},
#        'Humidity(SHT31_H)': {'doubleValue': 43.93},
#        'Luminance(VEML6030)': {'integerValue': '84'},
#        'VOC(CCS811)': {'integerValue': '0'},
#        'Humidity(SHT31_L)': {'doubleValue': 44.45},
#        'Pressure(BMP280)': {'doubleValue': 962.8886},
#        'UVIndex(VEML6075)': {'doubleValue': -244.3817},
#        'Altitude(BMP280)': {'doubleValue': 962.8886},
#        'Temperature(bmp280)': {'doubleValue': 27.94},
#        'UVA(VEML6075)': {'doubleValue': -167114.3},
#        'Bearing(Compass)': {'integerValue': '180'},
#        'Temperature(SHT31_H)': {'doubleValue': 26.4},
#        'eCO2(CCS811)': {'integerValue': '0'}}}},
#     'status': {'mapValue': {'fields': {'WiFi_Signal': {'integerValue': '-75'},
#        'Server_Status': {'integerValue': '0'},
#        'Date': {'stringValue': '2020-05-02'},
#        'Battery_Percent': {'integerValue': '82'},
#        'Sensors_Status': {'integerValue': '-1'},
#        'Time': {'stringValue': '12:09:03'},
#        'Battery_Status': {'integerValue': '2'},
#        'WiFI_Status': {'integerValue': '1'},
#        'MicroSD_Status': {'integerValue': '1'}}}},
#     'timestamp': {'integerValue': '1588414146320'},
#     'userInfo': {'mapValue': {'fields': {'userId': {'stringValue': 'lloyd.d.richards'},
#        'userName': {'stringValue': 'Lloyd'},
#        'ipAddress': {'stringValue': '77.109.177.45'},
#        'deviceId': {'stringValue': 'P3001'}}}}},
#    'createTime': '2020-05-02T10:09:08.037487Z',
#    'updateTime': '2020-05-02T10:09:08.037487Z'},
#   {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/01ZyiUiyZvucVJPfY5Zu',
#    'fields': {'timestamp': {'integerValue': '1567213127439'},
#     'weatherData': {'mapValue': {'fields': {'offset': {'integerValue': '1'},
#        'latitude': {'doubleValue': 51.6047},
#        'currently': {'mapValue': {'fields': {'apparentTemperature': {'doubleValue': 56.5},
#           'windGust': {'doubleValue': 15.51},
#           'temperature': {'doubleValue': 56.5},
#           'precipProbability': {'integerValue': '0'},
#           'uvIndex': {'integerValue': '0'},
#           'nearestStormDistance': {'integerValue': '122'},
#           'precipIntensity': {'integerValue': '0'},
#           'humidity': {'doubleValue': 0.86},
#           'cloudCover': {'doubleValue': 0.33},
#           'summary': {'stringValue': 'Partly Cloudy'},
#           'ozone': {'doubleValue': 277.8},
#           'pressure': {'doubleValue': 1015.68},
#           'dewPoint': {'doubleValue': 52.48},
#           'nearestStormBearing': {'integerValue': '4'},
#           'icon': {'stringValue': 'partly-cloudy-night'},
#           'visibility': {'doubleValue': 6.216},
#           'time': {'integerValue': '1567213126'},
#           'windBearing': {'integerValue': '179'},
#           'windSpeed': {'doubleValue': 4.52}}}},
#        'longitude': {'doubleValue': 0.4077},
#        'daily': {'mapValue': {'fields': {'icon': {'stringValue': 'rain'},
#           'data': {'arrayValue': {'values': [{'mapValue': {'fields': {'temperatureHigh': {'doubleValue': 76.43},
#                 'precipIntensityMaxTime': {'integerValue': '1567285200'},
#                 'precipProbability': {'doubleValue': 0.03},
#                 'apparentTemperatureLow': {'doubleValue': 50.34},
#                 'precipIntensity': {'doubleValue': 0.0001},
#                 'apparentTemperatureMax': {'doubleValue': 76.43},
#                 'windGust': {'doubleValue': 22.53},
#                 'temperatureLow': {'doubleValue': 50.34},
#                 'ozone': {'doubleValue': 286.2},
#                 'windBearing': {'integerValue': '237'},
#                 'temperatureLowTime': {'integerValue': '1567310400'},
#                 'apparentTemperatureLowTime': {'integerValue': '1567310400'},
#                 'windSpeed': {'doubleValue': 9.18},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'temperatureMax': {'doubleValue': 76.43},
#                 'apparentTemperatureHigh': {'doubleValue': 76.43},
#                 'precipType': {'stringValue': 'rain'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567256400'},
#                 'sunriseTime': {'integerValue': '1567228226'},
#                 'cloudCover': {'doubleValue': 0.46},
#                 'apparentTemperatureHighTime': {'integerValue': '1567256400'},
#                 'humidity': {'doubleValue': 0.73},
#                 'visibility': {'doubleValue': 9.431},
#                 'temperatureMaxTime': {'integerValue': '1567256400'},
#                 'uvIndexTime': {'integerValue': '1567249200'},
#                 'sunsetTime': {'integerValue': '1567277407'},
#                 'summary': {'stringValue': 'Mostly cloudy throughout the day.'},
#                 'uvIndex': {'integerValue': '5'},
#                 'apparentTemperatureMin': {'doubleValue': 52.85},
#                 'dewPoint': {'doubleValue': 53.49},
#                 'time': {'integerValue': '1567206000'},
#                 'windGustTime': {'integerValue': '1567263600'},
#                 'temperatureHighTime': {'integerValue': '1567256400'},
#                 'temperatureMinTime': {'integerValue': '1567227600'},
#                 'precipIntensityMax': {'doubleValue': 0.0006},
#                 'temperatureMin': {'doubleValue': 52.85},
#                 'pressure': {'doubleValue': 1012.16},
#                 'moonPhase': {'doubleValue': 0.06},
#                 'apparentTemperatureMinTime': {'integerValue': '1567227600'}}}},
#              {'mapValue': {'fields': {'windSpeed': {'doubleValue': 9.36},
#                 'apparentTemperatureLow': {'doubleValue': 40.74},
#                 'windGust': {'doubleValue': 22.2},
#                 'sunsetTime': {'integerValue': '1567363674'},
#                 'precipIntensityMaxTime': {'integerValue': '1567339200'},
#                 'dewPoint': {'integerValue': '46'},
#                 'precipProbability': {'doubleValue': 0.1},
#                 'apparentTemperatureMin': {'doubleValue': 50.34},
#                 'uvIndexTime': {'integerValue': '1567339200'},
#                 'precipIntensity': {'doubleValue': 0.0002},
#                 'precipType': {'stringValue': 'rain'},
#                 'temperatureLow': {'doubleValue': 44.64},
#                 'windBearing': {'integerValue': '289'},
#                 'windGustTime': {'integerValue': '1567375200'},
#                 'ozone': {'doubleValue': 299.7},
#                 'apparentTemperatureHigh': {'doubleValue': 66.36},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'humidity': {'doubleValue': 0.68},
#                 'temperatureHighTime': {'integerValue': '1567342800'},
#                 'moonPhase': {'doubleValue': 0.09},
#                 'temperatureMaxTime': {'integerValue': '1567342800'},
#                 'temperatureMax': {'doubleValue': 66.36},
#                 'temperatureLowTime': {'integerValue': '1567400400'},
#                 'apparentTemperatureMax': {'doubleValue': 66.36},
#                 'precipIntensityMax': {'doubleValue': 0.0009},
#                 'pressure': {'doubleValue': 1016.65},
#                 'visibility': {'integerValue': '10'},
#                 'cloudCover': {'doubleValue': 0.49},
#                 'sunriseTime': {'integerValue': '1567314722'},
#                 'temperatureHigh': {'doubleValue': 66.36},
#                 'time': {'integerValue': '1567292400'},
#                 'uvIndex': {'integerValue': '5'},
#                 'apparentTemperatureLowTime': {'integerValue': '1567400400'},
#                 'apparentTemperatureMinTime': {'integerValue': '1567310400'},
#                 'apparentTemperatureHighTime': {'integerValue': '1567342800'},
#                 'temperatureMin': {'doubleValue': 50.34},
#                 'temperatureMinTime': {'integerValue': '1567310400'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567342800'},
#                 'summary': {'stringValue': 'Partly cloudy throughout the day.'}}}},
#              {'mapValue': {'fields': {'time': {'integerValue': '1567378800'},
#                 'temperatureHigh': {'doubleValue': 69.64},
#                 'uvIndex': {'integerValue': '6'},
#                 'temperatureMaxTime': {'integerValue': '1567436400'},
#                 'windSpeed': {'doubleValue': 7.88},
#                 'temperatureLowTime': {'integerValue': '1567486800'},
#                 'ozone': {'doubleValue': 291.7},
#                 'visibility': {'integerValue': '10'},
#                 'precipIntensityMaxTime': {'integerValue': '1567447200'},
#                 'temperatureHighTime': {'integerValue': '1567436400'},
#                 'temperatureLow': {'doubleValue': 50.14},
#                 'precipIntensity': {'doubleValue': 0.0001},
#                 'apparentTemperatureMax': {'doubleValue': 69.64},
#                 'temperatureMinTime': {'integerValue': '1567400400'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567436400'},
#                 'apparentTemperatureHigh': {'doubleValue': 69.64},
#                 'uvIndexTime': {'integerValue': '1567425600'},
#                 'pressure': {'doubleValue': 1024.85},
#                 'temperatureMax': {'doubleValue': 69.64},
#                 'moonPhase': {'doubleValue': 0.13},
#                 'windGustTime': {'integerValue': '1567378800'},
#                 'precipIntensityMax': {'doubleValue': 0.0003},
#                 'windBearing': {'integerValue': '262'},
#                 'precipProbability': {'doubleValue': 0.02},
#                 'dewPoint': {'doubleValue': 45.84},
#                 'apparentTemperatureMinTime': {'integerValue': '1567400400'},
#                 'temperatureMin': {'doubleValue': 44.64},
#                 'icon': {'stringValue': 'clear-day'},
#                 'sunsetTime': {'integerValue': '1567449939'},
#                 'summary': {'stringValue': 'Clear throughout the day.'},
#                 'precipType': {'stringValue': 'rain'},
#                 'apparentTemperatureHighTime': {'integerValue': '1567436400'},
#                 'humidity': {'doubleValue': 0.7},
#                 'windGust': {'doubleValue': 21.91},
#                 'apparentTemperatureLowTime': {'integerValue': '1567486800'},
#                 'apparentTemperatureLow': {'doubleValue': 50.14},
#                 'sunriseTime': {'integerValue': '1567401218'},
#                 'apparentTemperatureMin': {'doubleValue': 40.74},
#                 'cloudCover': {'doubleValue': 0.01}}}},
#              {'mapValue': {'fields': {'icon': {'stringValue': 'partly-cloudy-day'},
#                 'visibility': {'integerValue': '10'},
#                 'windGustTime': {'integerValue': '1567551600'},
#                 'sunsetTime': {'integerValue': '1567536204'},
#                 'cloudCover': {'doubleValue': 0.3},
#                 'uvIndex': {'integerValue': '5'},
#                 'precipType': {'stringValue': 'rain'},
#                 'apparentTemperatureLowTime': {'integerValue': '1567576800'},
#                 'apparentTemperatureMin': {'doubleValue': 50.14},
#                 'precipProbability': {'doubleValue': 0.01},
#                 'summary': {'stringValue': 'Partly cloudy throughout the day.'},
#                 'temperatureLowTime': {'integerValue': '1567576800'},
#                 'windSpeed': {'doubleValue': 9.84},
#                 'temperatureMinTime': {'integerValue': '1567486800'},
#                 'apparentTemperatureMax': {'doubleValue': 73.55},
#                 'humidity': {'doubleValue': 0.73},
#                 'temperatureHighTime': {'integerValue': '1567522800'},
#                 'temperatureLow': {'doubleValue': 54.61},
#                 'temperatureMax': {'doubleValue': 73.55},
#                 'uvIndexTime': {'integerValue': '1567512000'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567522800'},
#                 'windBearing': {'integerValue': '238'},
#                 'apparentTemperatureLow': {'doubleValue': 54.61},
#                 'sunriseTime': {'integerValue': '1567487713'},
#                 'temperatureMaxTime': {'integerValue': '1567522800'},
#                 'precipIntensity': {'doubleValue': 0.0001},
#                 'temperatureHigh': {'doubleValue': 73.55},
#                 'precipIntensityMaxTime': {'integerValue': '1567551600'},
#                 'moonPhase': {'doubleValue': 0.17},
#                 'apparentTemperatureMinTime': {'integerValue': '1567486800'},
#                 'time': {'integerValue': '1567465200'},
#                 'ozone': {'doubleValue': 279.6},
#                 'temperatureMin': {'doubleValue': 50.14},
#                 'dewPoint': {'doubleValue': 51.66},
#                 'pressure': {'doubleValue': 1024.41},
#                 'precipIntensityMax': {'doubleValue': 0.0012},
#                 'apparentTemperatureHigh': {'doubleValue': 73.55},
#                 'windGust': {'doubleValue': 22.4},
#                 'apparentTemperatureHighTime': {'integerValue': '1567522800'}}}},
#              {'mapValue': {'fields': {'time': {'integerValue': '1567551600'},
#                 'windBearing': {'integerValue': '290'},
#                 'apparentTemperatureMax': {'doubleValue': 66.52},
#                 'precipIntensity': {'doubleValue': 0.0015},
#                 'summary': {'stringValue': 'Partly cloudy throughout the day.'},
#                 'apparentTemperatureLow': {'doubleValue': 43.63},
#                 'windSpeed': {'doubleValue': 11.87},
#                 'precipIntensityMax': {'doubleValue': 0.0061},
#                 'apparentTemperatureHighTime': {'integerValue': '1567609200'},
#                 'temperatureHigh': {'doubleValue': 66.52},
#                 'apparentTemperatureLowTime': {'integerValue': '1567656000'},
#                 'apparentTemperatureMinTime': {'integerValue': '1567638000'},
#                 'uvIndex': {'integerValue': '5'},
#                 'temperatureMin': {'doubleValue': 53.62},
#                 'apparentTemperatureMin': {'doubleValue': 53.62},
#                 'windGust': {'doubleValue': 24.74},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567609200'},
#                 'precipIntensityMaxTime': {'integerValue': '1567576800'},
#                 'temperatureMinTime': {'integerValue': '1567638000'},
#                 'uvIndexTime': {'integerValue': '1567598400'},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'precipType': {'stringValue': 'rain'},
#                 'cloudCover': {'doubleValue': 0.49},
#                 'precipProbability': {'doubleValue': 0.19},
#                 'sunriseTime': {'integerValue': '1567574209'},
#                 'temperatureMax': {'doubleValue': 66.52},
#                 'visibility': {'integerValue': '10'},
#                 'dewPoint': {'doubleValue': 50.3},
#                 'sunsetTime': {'integerValue': '1567622469'},
#                 'windGustTime': {'integerValue': '1567609200'},
#                 'pressure': {'doubleValue': 1022.05},
#                 'temperatureHighTime': {'integerValue': '1567609200'},
#                 'temperatureLow': {'doubleValue': 47.78},
#                 'humidity': {'doubleValue': 0.73},
#                 'apparentTemperatureHigh': {'doubleValue': 66.52},
#                 'moonPhase': {'doubleValue': 0.21},
#                 'temperatureMaxTime': {'integerValue': '1567609200'},
#                 'ozone': {'integerValue': '312'},
#                 'temperatureLowTime': {'integerValue': '1567656000'}}}},
#              {'mapValue': {'fields': {'pressure': {'doubleValue': 1025.77},
#                 'temperatureMinTime': {'integerValue': '1567656000'},
#                 'temperatureMin': {'doubleValue': 47.78},
#                 'sunsetTime': {'integerValue': '1567708733'},
#                 'summary': {'stringValue': 'Possible drizzle in the morning.'},
#                 'precipProbability': {'doubleValue': 0.34},
#                 'apparentTemperatureHigh': {'doubleValue': 64.85},
#                 'uvIndex': {'integerValue': '4'},
#                 'windGustTime': {'integerValue': '1567638000'},
#                 'apparentTemperatureLowTime': {'integerValue': '1567746000'},
#                 'precipType': {'stringValue': 'rain'},
#                 'time': {'integerValue': '1567638000'},
#                 'sunriseTime': {'integerValue': '1567660704'},
#                 'precipIntensity': {'doubleValue': 0.0014},
#                 'temperatureHigh': {'doubleValue': 64.85},
#                 'temperatureMax': {'doubleValue': 64.85},
#                 'temperatureMaxTime': {'integerValue': '1567695600'},
#                 'uvIndexTime': {'integerValue': '1567684800'},
#                 'ozone': {'doubleValue': 321.1},
#                 'temperatureHighTime': {'integerValue': '1567695600'},
#                 'apparentTemperatureMax': {'doubleValue': 64.85},
#                 'windGust': {'doubleValue': 22.96},
#                 'apparentTemperatureHighTime': {'integerValue': '1567695600'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567695600'},
#                 'cloudCover': {'doubleValue': 0.41},
#                 'moonPhase': {'doubleValue': 0.24},
#                 'icon': {'stringValue': 'rain'},
#                 'apparentTemperatureLow': {'doubleValue': 43.13},
#                 'apparentTemperatureMin': {'doubleValue': 43.63},
#                 'windBearing': {'integerValue': '321'},
#                 'apparentTemperatureMinTime': {'integerValue': '1567656000'},
#                 'humidity': {'doubleValue': 0.7},
#                 'temperatureLow': {'doubleValue': 46.51},
#                 'precipIntensityMax': {'doubleValue': 0.0095},
#                 'windSpeed': {'doubleValue': 9.67},
#                 'visibility': {'integerValue': '10'},
#                 'temperatureLowTime': {'integerValue': '1567746000'},
#                 'dewPoint': {'doubleValue': 44.75},
#                 'precipIntensityMaxTime': {'integerValue': '1567663200'}}}},
#              {'mapValue': {'fields': {'cloudCover': {'doubleValue': 0.71},
#                 'humidity': {'doubleValue': 0.67},
#                 'moonPhase': {'doubleValue': 0.27},
#                 'apparentTemperatureHigh': {'doubleValue': 68.47},
#                 'apparentTemperatureMin': {'doubleValue': 43.13},
#                 'temperatureHigh': {'doubleValue': 68.47},
#                 'temperatureMin': {'doubleValue': 46.51},
#                 'windGustTime': {'integerValue': '1567810800'},
#                 'pressure': {'doubleValue': 1025.7},
#                 'temperatureLow': {'doubleValue': 53.86},
#                 'precipIntensityMax': {'doubleValue': 0.0004},
#                 'apparentTemperatureLowTime': {'integerValue': '1567832400'},
#                 'sunriseTime': {'integerValue': '1567747200'},
#                 'visibility': {'integerValue': '10'},
#                 'windBearing': {'integerValue': '284'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567782000'},
#                 'sunsetTime': {'integerValue': '1567794996'},
#                 'temperatureMax': {'doubleValue': 68.47},
#                 'windGust': {'doubleValue': 27.98},
#                 'temperatureMinTime': {'integerValue': '1567746000'},
#                 'uvIndexTime': {'integerValue': '1567771200'},
#                 'temperatureMaxTime': {'integerValue': '1567782000'},
#                 'time': {'integerValue': '1567724400'},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'apparentTemperatureLow': {'doubleValue': 53.86},
#                 'ozone': {'doubleValue': 307.1},
#                 'precipType': {'stringValue': 'rain'},
#                 'precipIntensityMaxTime': {'integerValue': '1567792800'},
#                 'uvIndex': {'integerValue': '4'},
#                 'apparentTemperatureMax': {'doubleValue': 68.47},
#                 'windSpeed': {'doubleValue': 8.78},
#                 'temperatureHighTime': {'integerValue': '1567782000'},
#                 'precipIntensity': {'doubleValue': 0.0001},
#                 'summary': {'stringValue': 'Mostly cloudy throughout the day.'},
#                 'temperatureLowTime': {'integerValue': '1567832400'},
#                 'dewPoint': {'doubleValue': 44.88},
#                 'apparentTemperatureMinTime': {'integerValue': '1567746000'},
#                 'apparentTemperatureHighTime': {'integerValue': '1567782000'},
#                 'precipProbability': {'doubleValue': 0.09}}}},
#              {'mapValue': {'fields': {'apparentTemperatureMax': {'doubleValue': 66.51},
#                 'temperatureMin': {'doubleValue': 53.86},
#                 'temperatureHigh': {'doubleValue': 66.51},
#                 'ozone': {'doubleValue': 316.3},
#                 'precipIntensityMax': {'doubleValue': 0.0037},
#                 'moonPhase': {'doubleValue': 0.31},
#                 'precipIntensity': {'doubleValue': 0.001},
#                 'precipIntensityMaxTime': {'integerValue': '1567825200'},
#                 'cloudCover': {'doubleValue': 0.69},
#                 'temperatureLowTime': {'integerValue': '1567915200'},
#                 'windGust': {'doubleValue': 30.32},
#                 'visibility': {'integerValue': '10'},
#                 'apparentTemperatureMin': {'doubleValue': 53.86},
#                 'apparentTemperatureHighTime': {'integerValue': '1567864800'},
#                 'uvIndexTime': {'integerValue': '1567857600'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567864800'},
#                 'temperatureHighTime': {'integerValue': '1567864800'},
#                 'pressure': {'doubleValue': 1016.9},
#                 'precipProbability': {'doubleValue': 0.34},
#                 'temperatureLow': {'doubleValue': 51.12},
#                 'time': {'integerValue': '1567810800'},
#                 'windGustTime': {'integerValue': '1567890000'},
#                 'sunriseTime': {'integerValue': '1567833695'},
#                 'humidity': {'doubleValue': 0.71},
#                 'dewPoint': {'doubleValue': 48.91},
#                 'precipType': {'stringValue': 'rain'},
#                 'apparentTemperatureHigh': {'doubleValue': 66.51},
#                 'apparentTemperatureMinTime': {'integerValue': '1567832400'},
#                 'temperatureMaxTime': {'integerValue': '1567864800'},
#                 'temperatureMax': {'doubleValue': 66.51},
#                 'sunsetTime': {'integerValue': '1567881259'},
#                 'temperatureMinTime': {'integerValue': '1567832400'},
#                 'summary': {'stringValue': 'Mostly cloudy throughout the day.'},
#                 'apparentTemperatureLowTime': {'integerValue': '1567915200'},
#                 'apparentTemperatureLow': {'doubleValue': 51.12},
#                 'windSpeed': {'doubleValue': 16.71},
#                 'uvIndex': {'integerValue': '4'},
#                 'windBearing': {'integerValue': '314'},
#                 'icon': {'stringValue': 'rain'}}}}]}},
#           'summary': {'stringValue': 'Possible drizzle on Thursday and next Saturday, with high temperatures falling to 65°F on Thursday.'}}}},
#        'timezone': {'stringValue': 'Europe/London'}}}},
#     'sensor': {'mapValue': {'fields': {'uvb': {'integerValue': '0'},
#        'humidity': {'doubleValue': 67.61686},
#        'illuminance': {'doubleValue': 11.29032},
#        'pressure': {'doubleValue': 101.091},
#        'temperature': {'doubleValue': 24.22108},
#        'uvIndex': {'integerValue': '0'},
#        'uva': {'integerValue': '0'}}}},
#     'airData': {'mapValue': {'fields': {'meta': {'mapValue': {'fields': {'found': {'integerValue': '0'},
#           'page': {'integerValue': '1'},
#           'license': {'stringValue': 'CC BY 4.0'},
#           'website': {'stringValue': 'https://docs.openaq.org/'},
#           'name': {'stringValue': 'openaq-api'},
#           'limit': {'integerValue': '100'}}}},
#        'results': {'arrayValue': {}}}}},
#     'deviceLocation': {'mapValue': {'fields': {'houseType': {'stringValue': 'Semi-detached'},
#        'windowExposure': {'stringValue': 'East'},
#        'room': {'stringValue': 'bedroom'},
#        'floor': {'integerValue': '1'},
#        'position': {'stringValue': 'Window sill'}}}},
#     'userInfo': {'mapValue': {'fields': {'userName': {'stringValue': 'Dan Harrington'},
#        'userId': {'stringValue': 'LLNC7iSB1wdV7h6OjoTjxmtMU4B2'},
#        'deviceId': {'stringValue': 'YAoG5yyb4xUhsRsjgCVl'},
#        'ipAddress': {'stringValue': '109.151.10.194'}}}},
#     'instance': {'mapValue': {'fields': {'dataNumber': {'integerValue': '0'}}}}},
#    'createTime': '2019-08-31T00:58:49.451727Z',
#    'updateTime': '2019-08-31T00:58:49.451727Z'},
#   {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/02Hv7BhciapHB8gzikRb',
#    'fields': {'userInfo': {'mapValue': {'fields': {'userId': {'stringValue': '2001_PROTOTYPE'},
#        'userName': {'stringValue': 'Lloyd Richards'},
#        'ipAddress': {'stringValue': '92.107.36.43'},
#        'deviceId': {'stringValue': 'PROTOTYPE2_01'}}}},
#     'timestamp': {'integerValue': '1585164497238'},
#     'data': {'mapValue': {'fields': {'temperature': {'doubleValue': 38.59422},
#        'illuminance': {'integerValue': '0'},
#        'humidity': {'doubleValue': 22.63971}}}}},
#    'createTime': '2020-03-25T19:28:17.380879Z',
#    'updateTime': '2020-03-25T19:28:17.380879Z'},
#   {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/02JzrbpzbyXCeRKvrmq8',
#    'fields': {'userInfo': {'mapValue': {'fields': {'ipAddress': {'stringValue': '92.107.36.43'},
#        'userId': {'stringValue': '2001_PROTOTYPE'},
#        'userName': {'stringValue': 'Lloyd Richards'},
#        'deviceId': {'stringValue': 'PROTOTYPE2_01'}}}},
#     'data': {'mapValue': {'fields': {'illuminance': {'integerValue': '0'},
#        'humidity': {'doubleValue': 21.46324},
#        'temperature': {'doubleValue': 41.18951}}}},
#     'timestamp': {'integerValue': '1585460423676'}},
#    'createTime': '2020-03-29T05:40:23.836079Z',
#    'updateTime': '2020-03-29T05:40:23.836079Z'},
#   {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/02OhgRYFODDdAdEaU3sx',
#    'fields': {'status': {'mapValue': {'fields': {'Server Status': {'integerValue': '1'},
#        'Sensors Status': {'integerValue': '0'},
#        'MicroSD Status': {'integerValue': '0'},
#        'Battery Status': {'integerValue': '0'},
#        'WiFI Status': {'integerValue': '1'}}}},
#     'timestamp': {'integerValue': '1586189346709'},
#     'data': {'mapValue': {'fields': {'eCO2 (CCS811)': {'integerValue': '0'},
#        'Humidity (SHT31_L)': {'nullValue': None},
#        'Luminance (BH1715_L)': {'integerValue': '923746500'},
#        'Temperature (SHT31_H)': {'doubleValue': 24.79},
#        'Humidity (SHT31_H)': {'doubleValue': 18.46},
#        'VOC (CCS811)': {'integerValue': '0'},
#        'Temperature (BME280)': {'doubleValue': 26.71},
#        'Humidity (BME280)': {'integerValue': '0'},
#        'Temperature (SHT31_L)': {'nullValue': None},
#        'Luminance (BH1715_H)': {'integerValue': '923746500'},
#        'Pressure (BME280)': {'doubleValue': 97430.11},
#        'Luminance (TEMT600)': {'integerValue': '48'},
#        'Luminance (VEML6030)': {'integerValue': '436'}}}},
#     'userInfo': {'mapValue': {'fields': {'userName': {'stringValue': 'Lloyd Richards'},
#        'ipAddress': {'stringValue': '92.107.36.43'},
#        'deviceId': {'stringValue': 'PROTOTYPE3_04'},
#        'userId': {'stringValue': 'P2003_PROTOTYPE'}}}}},
#    'createTime': '2020-04-06T16:09:06.865135Z',
#    'updateTime': '2020-04-06T16:09:06.865135Z'},
#   {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/02TIpioWKQ21nxQXWDmn',
#    'fields': {'data': {'mapValue': {'fields': {'illuminance': {'integerValue': '0'},
#        'humidity': {'doubleValue': 21.94118},
#        'temperature': {'doubleValue': 42.42213}}}},
#     'timestamp': {'integerValue': '1585256913438'},
#     'userInfo': {'mapValue': {'fields': {'userId': {'stringValue': '2001_PROTOTYPE'},
#        'ipAddress': {'stringValue': '92.107.36.43'},
#        'deviceId': {'stringValue': 'PROTOTYPE2_01'},
#        'userName': {'stringValue': 'Lloyd Richards'}}}}},
#    'createTime': '2020-03-26T21:08:34.656495Z',
#    'updateTime': '2020-03-26T21:08:34.656495Z'},
#   {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/02XZN9xqn0Fn3lfMOC5c',
#    'fields': {'timestamp': {'integerValue': '1589923854320'},
#     'status': {'mapValue': {'fields': {'Sensors_Status': {'integerValue': '1'},
#        'MicroSD_Status': {'integerValue': '1'},
#        'Battery_Status': {'integerValue': '2'},
#        'Server_Status': {'integerValue': '1'},
#        'Date': {'stringValue': '2020-05-19'},
#        'WiFI_Status': {'integerValue': '1'},
#        'Time': {'stringValue': '23:30:48'},
#        'Battery_Percent': {'integerValue': '69'},
#        'WiFi_Signal': {'integerValue': '-62'}}}},
#     'userInfo': {'mapValue': {'fields': {'userId': {'stringValue': 'lloyd.d.richards'},
#        'deviceId': {'stringValue': 'P3003'},
#        'macAddress': {'stringValue': '24:6F:28:B1:D5:30'},
#        'ipAddress': {'stringValue': '62.203.6.17'},
#        'userName': {'stringValue': 'Lloyd'}}}},
#     'data': {'mapValue': {'fields': {'UVB(VEML6075)': {'integerValue': '0'},
#        'VOC(CCS811)': {'integerValue': '1542'},
#        'Bearing(Compass)': {'doubleValue': 161.565},
#        'Humidity(SHT31_L)': {'doubleValue': 31.25},
#        'Humidity(SHT31_H)': {'doubleValue': 30.32},
#        'UVA(VEML6075)': {'integerValue': '11'},
#        'eCO2(CCS811)': {'integerValue': '2386'},
#        'UVIndex(VEML6075)': {'doubleValue': 0.00611},
#        'Temperature(SHT31_L)': {'doubleValue': 27.07},
#        'Temperature(SHT31_H)': {'doubleValue': 26.8},
#        'Luminance(VEML6030)': {'integerValue': '65'},
#        'Pressure(BMP280)': {'doubleValue': 971.4904},
#        'Temperature(bmp280)': {'doubleValue': 28.42},
#        'Altitude(BMP280)': {'doubleValue': 971.4904}}}}},
#    'createTime': '2020-05-19T21:30:54.420719Z',
#    'updateTime': '2020-05-19T21:30:54.420719Z'},
#   {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/030dcxjX3Dn1vSNp9YAG',
#    'fields': {'deviceLocation': {'mapValue': {'fields': {'houseType': {'stringValue': 'Apartment'},
#        'position': {'stringValue': 'Window sill'},
#        'room': {'stringValue': 'bedroom'},
#        'windowExposure': {'stringValue': 'North'},
#        'floor': {'integerValue': '3'}}}},
#     'weatherData': {'mapValue': {'fields': {'timezone': {'stringValue': 'Europe/Berlin'},
#        'daily': {'mapValue': {'fields': {'summary': {'stringValue': 'Light rain on Saturday through next Wednesday, with high temperatures falling to 63°F on Monday.'},
#           'data': {'arrayValue': {'values': [{'mapValue': {'fields': {'windBearing': {'integerValue': '216'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567609200'},
#                 'temperatureMaxTime': {'integerValue': '1567609200'},
#                 'apparentTemperatureHigh': {'doubleValue': 79.1},
#                 'humidity': {'doubleValue': 0.62},
#                 'temperatureLow': {'doubleValue': 57.95},
#                 'summary': {'stringValue': 'Partly cloudy throughout the day.'},
#                 'temperatureLowTime': {'integerValue': '1567659600'},
#                 'uvIndexTime': {'integerValue': '1567594800'},
#                 'precipIntensity': {'doubleValue': 0.0001},
#                 'apparentTemperatureHighTime': {'integerValue': '1567609200'},
#                 'ozone': {'doubleValue': 277.4},
#                 'precipIntensityMax': {'doubleValue': 0.0004},
#                 'uvIndex': {'integerValue': '5'},
#                 'apparentTemperatureMin': {'doubleValue': 56.24},
#                 'temperatureHigh': {'doubleValue': 79.1},
#                 'apparentTemperatureMax': {'doubleValue': 79.1},
#                 'temperatureMin': {'doubleValue': 56.24},
#                 'windGust': {'doubleValue': 19.12},
#                 'cloudCover': {'doubleValue': 0.43},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'precipType': {'stringValue': 'rain'},
#                 'windSpeed': {'doubleValue': 6.38},
#                 'precipIntensityMaxTime': {'integerValue': '1567566000'},
#                 'apparentTemperatureLow': {'doubleValue': 57.95},
#                 'visibility': {'doubleValue': 8.22},
#                 'sunriseTime': {'integerValue': '1567570998'},
#                 'temperatureMinTime': {'integerValue': '1567558800'},
#                 'temperatureMax': {'doubleValue': 79.1},
#                 'time': {'integerValue': '1567548000'},
#                 'apparentTemperatureMinTime': {'integerValue': '1567558800'},
#                 'temperatureHighTime': {'integerValue': '1567609200'},
#                 'dewPoint': {'doubleValue': 51.66},
#                 'precipProbability': {'doubleValue': 0.05},
#                 'windGustTime': {'integerValue': '1567609200'},
#                 'moonPhase': {'doubleValue': 0.2},
#                 'apparentTemperatureLowTime': {'integerValue': '1567659600'},
#                 'pressure': {'doubleValue': 1016.73},
#                 'sunsetTime': {'integerValue': '1567619441'}}}},
#              {'mapValue': {'fields': {'uvIndexTime': {'integerValue': '1567681200'},
#                 'windGust': {'doubleValue': 22.18},
#                 'windBearing': {'integerValue': '269'},
#                 'precipIntensity': {'doubleValue': 0.0006},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'precipIntensityMax': {'doubleValue': 0.0031},
#                 'visibility': {'integerValue': '10'},
#                 'apparentTemperatureMin': {'doubleValue': 55.32},
#                 'sunsetTime': {'integerValue': '1567705700'},
#                 'apparentTemperatureMinTime': {'integerValue': '1567720800'},
#                 'cloudCover': {'doubleValue': 0.55},
#                 'ozone': {'doubleValue': 290.3},
#                 'apparentTemperatureHigh': {'doubleValue': 69.32},
#                 'dewPoint': {'doubleValue': 50.57},
#                 'temperatureMin': {'doubleValue': 55.32},
#                 'temperatureMinTime': {'integerValue': '1567720800'},
#                 'temperatureMaxTime': {'integerValue': '1567688400'},
#                 'apparentTemperatureMax': {'doubleValue': 69.32},
#                 'pressure': {'doubleValue': 1014.9},
#                 'temperatureLow': {'doubleValue': 48.1},
#                 'temperatureMax': {'doubleValue': 69.32},
#                 'temperatureLowTime': {'integerValue': '1567746000'},
#                 'windSpeed': {'doubleValue': 10.83},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567688400'},
#                 'apparentTemperatureLowTime': {'integerValue': '1567746000'},
#                 'humidity': {'doubleValue': 0.66},
#                 'temperatureHigh': {'doubleValue': 69.32},
#                 'precipProbability': {'doubleValue': 0.15},
#                 'summary': {'stringValue': 'Mostly cloudy throughout the day.'},
#                 'apparentTemperatureLow': {'doubleValue': 44.71},
#                 'temperatureHighTime': {'integerValue': '1567688400'},
#                 'precipType': {'stringValue': 'rain'},
#                 'apparentTemperatureHighTime': {'integerValue': '1567688400'},
#                 'precipIntensityMaxTime': {'integerValue': '1567652400'},
#                 'windGustTime': {'integerValue': '1567713600'},
#                 'sunriseTime': {'integerValue': '1567657498'},
#                 'moonPhase': {'doubleValue': 0.24},
#                 'uvIndex': {'integerValue': '5'},
#                 'time': {'integerValue': '1567634400'}}}},
#              {'mapValue': {'fields': {'dewPoint': {'doubleValue': 42.73},
#                 'visibility': {'integerValue': '10'},
#                 'pressure': {'doubleValue': 1023.04},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567782000'},
#                 'apparentTemperatureHigh': {'doubleValue': 67.64},
#                 'apparentTemperatureMin': {'doubleValue': 44.71},
#                 'cloudCover': {'doubleValue': 0.44},
#                 'sunsetTime': {'integerValue': '1567791960'},
#                 'uvIndexTime': {'integerValue': '1567767600'},
#                 'temperatureMaxTime': {'integerValue': '1567782000'},
#                 'sunriseTime': {'integerValue': '1567743998'},
#                 'temperatureLowTime': {'integerValue': '1567825200'},
#                 'apparentTemperatureHighTime': {'integerValue': '1567782000'},
#                 'windGust': {'doubleValue': 22.51},
#                 'apparentTemperatureMinTime': {'integerValue': '1567746000'},
#                 'precipIntensity': {'doubleValue': 0.0001},
#                 'temperatureMinTime': {'integerValue': '1567746000'},
#                 'apparentTemperatureMax': {'doubleValue': 67.64},
#                 'precipIntensityMax': {'doubleValue': 0.0003},
#                 'ozone': {'doubleValue': 304.7},
#                 'moonPhase': {'doubleValue': 0.27},
#                 'temperatureLow': {'doubleValue': 49.07},
#                 'temperatureMax': {'doubleValue': 67.64},
#                 'summary': {'stringValue': 'Mostly cloudy throughout the day.'},
#                 'temperatureHighTime': {'integerValue': '1567782000'},
#                 'windSpeed': {'doubleValue': 6.9},
#                 'humidity': {'doubleValue': 0.62},
#                 'uvIndex': {'integerValue': '5'},
#                 'temperatureHigh': {'doubleValue': 67.64},
#                 'temperatureMin': {'doubleValue': 48.1},
#                 'precipType': {'stringValue': 'rain'},
#                 'windGustTime': {'integerValue': '1567735200'},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'precipProbability': {'doubleValue': 0.08},
#                 'apparentTemperatureLowTime': {'integerValue': '1567825200'},
#                 'time': {'integerValue': '1567720800'},
#                 'precipIntensityMaxTime': {'integerValue': '1567735200'},
#                 'windBearing': {'integerValue': '261'},
#                 'apparentTemperatureLow': {'doubleValue': 46.87}}}},
#              {'mapValue': {'fields': {'windBearing': {'integerValue': '200'},
#                 'precipIntensityMaxTime': {'integerValue': '1567879200'},
#                 'moonPhase': {'doubleValue': 0.3},
#                 'summary': {'stringValue': 'Overcast throughout the day.'},
#                 'precipIntensityMax': {'doubleValue': 0.0081},
#                 'cloudCover': {'doubleValue': 0.87},
#                 'apparentTemperatureLow': {'doubleValue': 50.8},
#                 'apparentTemperatureMax': {'doubleValue': 66.1},
#                 'windGustTime': {'integerValue': '1567857600'},
#                 'windSpeed': {'doubleValue': 4.93},
#                 'temperatureMaxTime': {'integerValue': '1567868400'},
#                 'apparentTemperatureHigh': {'doubleValue': 66.1},
#                 'temperatureHigh': {'doubleValue': 66.1},
#                 'temperatureHighTime': {'integerValue': '1567868400'},
#                 'temperatureLowTime': {'integerValue': '1567918800'},
#                 'windGust': {'doubleValue': 15.79},
#                 'precipIntensity': {'doubleValue': 0.0019},
#                 'temperatureMinTime': {'integerValue': '1567825200'},
#                 'pressure': {'doubleValue': 1018.66},
#                 'apparentTemperatureMinTime': {'integerValue': '1567825200'},
#                 'temperatureLow': {'doubleValue': 50.8},
#                 'apparentTemperatureMin': {'doubleValue': 46.87},
#                 'dewPoint': {'doubleValue': 41.94},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567868400'},
#                 'apparentTemperatureLowTime': {'integerValue': '1567918800'},
#                 'ozone': {'doubleValue': 308.7},
#                 'uvIndex': {'integerValue': '3'},
#                 'humidity': {'doubleValue': 0.57},
#                 'temperatureMax': {'doubleValue': 66.1},
#                 'sunriseTime': {'integerValue': '1567830497'},
#                 'temperatureMin': {'doubleValue': 49.07},
#                 'uvIndexTime': {'integerValue': '1567854000'},
#                 'precipType': {'stringValue': 'rain'},
#                 'apparentTemperatureHighTime': {'integerValue': '1567868400'},
#                 'sunsetTime': {'integerValue': '1567878218'},
#                 'time': {'integerValue': '1567807200'},
#                 'precipProbability': {'doubleValue': 0.32},
#                 'icon': {'stringValue': 'rain'},
#                 'visibility': {'doubleValue': 9.919}}}},
#              {'mapValue': {'fields': {'ozone': {'doubleValue': 319.8},
#                 'temperatureMinTime': {'integerValue': '1567918800'},
#                 'apparentTemperatureMinTime': {'integerValue': '1567918800'},
#                 'cloudCover': {'doubleValue': 0.86},
#                 'windGustTime': {'integerValue': '1567893600'},
#                 'precipIntensity': {'doubleValue': 0.0027},
#                 'time': {'integerValue': '1567893600'},
#                 'windGust': {'doubleValue': 7.66},
#                 'sunriseTime': {'integerValue': '1567916997'},
#                 'uvIndexTime': {'integerValue': '1567940400'},
#                 'icon': {'stringValue': 'rain'},
#                 'humidity': {'doubleValue': 0.7},
#                 'uvIndex': {'integerValue': '4'},
#                 'apparentTemperatureLowTime': {'integerValue': '1568005200'},
#                 'temperatureMaxTime': {'integerValue': '1567947600'},
#                 'moonPhase': {'doubleValue': 0.34},
#                 'apparentTemperatureMin': {'doubleValue': 50.8},
#                 'dewPoint': {'doubleValue': 48.23},
#                 'summary': {'stringValue': 'Possible light rain in the morning and overnight.'},
#                 'apparentTemperatureMax': {'doubleValue': 66.9},
#                 'precipType': {'stringValue': 'rain'},
#                 'temperatureLow': {'doubleValue': 54.23},
#                 'visibility': {'integerValue': '10'},
#                 'temperatureLowTime': {'integerValue': '1568005200'},
#                 'apparentTemperatureLow': {'doubleValue': 54.23},
#                 'precipIntensityMax': {'doubleValue': 0.0294},
#                 'windSpeed': {'doubleValue': 3.01},
#                 'temperatureHigh': {'doubleValue': 66.9},
#                 'precipIntensityMaxTime': {'integerValue': '1567980000'},
#                 'precipProbability': {'doubleValue': 0.42},
#                 'temperatureHighTime': {'integerValue': '1567947600'},
#                 'apparentTemperatureHigh': {'doubleValue': 66.9},
#                 'windBearing': {'integerValue': '334'},
#                 'apparentTemperatureHighTime': {'integerValue': '1567947600'},
#                 'temperatureMax': {'doubleValue': 66.9},
#                 'pressure': {'doubleValue': 1017.56},
#                 'temperatureMin': {'doubleValue': 50.8},
#                 'sunsetTime': {'integerValue': '1567964477'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567947600'}}}},
#              {'mapValue': {'fields': {'apparentTemperatureMax': {'doubleValue': 62.65},
#                 'apparentTemperatureHighTime': {'integerValue': '1568030400'},
#                 'temperatureHigh': {'doubleValue': 62.65},
#                 'temperatureMaxTime': {'integerValue': '1568030400'},
#                 'temperatureMin': {'doubleValue': 53.57},
#                 'apparentTemperatureHigh': {'doubleValue': 62.65},
#                 'precipProbability': {'doubleValue': 0.98},
#                 'apparentTemperatureMaxTime': {'integerValue': '1568030400'},
#                 'windGustTime': {'integerValue': '1568066400'},
#                 'apparentTemperatureLowTime': {'integerValue': '1568091600'},
#                 'humidity': {'doubleValue': 0.79},
#                 'precipType': {'stringValue': 'rain'},
#                 'precipIntensityMax': {'doubleValue': 0.0793},
#                 'summary': {'stringValue': 'Light rain until evening.'},
#                 'temperatureMinTime': {'integerValue': '1568066400'},
#                 'temperatureMax': {'doubleValue': 62.65},
#                 'windSpeed': {'doubleValue': 8.26},
#                 'temperatureLowTime': {'integerValue': '1568091600'},
#                 'ozone': {'doubleValue': 311.1},
#                 'temperatureLow': {'doubleValue': 49.93},
#                 'time': {'integerValue': '1567980000'},
#                 'apparentTemperatureMin': {'doubleValue': 53.57},
#                 'windGust': {'doubleValue': 23.01},
#                 'uvIndexTime': {'integerValue': '1568026800'},
#                 'temperatureHighTime': {'integerValue': '1568030400'},
#                 'precipIntensity': {'doubleValue': 0.036},
#                 'precipIntensityMaxTime': {'integerValue': '1568005200'},
#                 'sunsetTime': {'integerValue': '1568050735'},
#                 'apparentTemperatureMinTime': {'integerValue': '1568066400'},
#                 'sunriseTime': {'integerValue': '1568003496'},
#                 'apparentTemperatureLow': {'doubleValue': 46.91},
#                 'pressure': {'doubleValue': 1012.93},
#                 'cloudCover': {'doubleValue': 0.98},
#                 'icon': {'stringValue': 'rain'},
#                 'dewPoint': {'doubleValue': 50.48},
#                 'visibility': {'integerValue': '10'},
#                 'windBearing': {'integerValue': '322'},
#                 'uvIndex': {'integerValue': '3'},
#                 'moonPhase': {'doubleValue': 0.37}}}},
#              {'mapValue': {'fields': {'apparentTemperatureMaxTime': {'integerValue': '1568124000'},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'apparentTemperatureHighTime': {'integerValue': '1568124000'},
#                 'temperatureMinTime': {'integerValue': '1568091600'},
#                 'precipIntensity': {'doubleValue': 0.0004},
#                 'uvIndex': {'integerValue': '3'},
#                 'pressure': {'doubleValue': 1009.78},
#                 'time': {'integerValue': '1568066400'},
#                 'sunriseTime': {'integerValue': '1568089996'},
#                 'moonPhase': {'doubleValue': 0.4},
#                 'windGustTime': {'integerValue': '1568095200'},
#                 'precipIntensityMaxTime': {'integerValue': '1568116800'},
#                 'precipType': {'stringValue': 'rain'},
#                 'visibility': {'integerValue': '10'},
#                 'temperatureMax': {'doubleValue': 62.73},
#                 'temperatureMaxTime': {'integerValue': '1568124000'},
#                 'apparentTemperatureMin': {'doubleValue': 46.91},
# ...
#                 'pressure': {'doubleValue': 1023.1},
#                 'apparentTemperatureLow': {'doubleValue': 44.34},
#                 'humidity': {'doubleValue': 0.65},
#                 'temperatureLow': {'doubleValue': 46.32},
#                 'ozone': {'doubleValue': 311.4},
#                 'time': {'integerValue': '1567897200'},
#                 'windBearing': {'integerValue': '342'},
#                 'uvIndex': {'integerValue': '4'},
#                 'windGust': {'doubleValue': 18.76},
#                 'apparentTemperatureMaxTime': {'integerValue': '1567954800'},
#                 'temperatureMaxTime': {'integerValue': '1567954800'},
#                 'cloudCover': {'doubleValue': 0.34},
#                 'precipIntensityMaxTime': {'integerValue': '1567922400'}}}},
#              {'mapValue': {'fields': {'precipProbability': {'doubleValue': 0.79},
#                 'temperatureMax': {'doubleValue': 61.21},
#                 'uvIndexTime': {'integerValue': '1568030400'},
#                 'apparentTemperatureLow': {'doubleValue': 50.65},
#                 'apparentTemperatureMin': {'doubleValue': 44.34},
#                 'sunsetTime': {'integerValue': '1568053784'},
#                 'temperatureLow': {'doubleValue': 50.65},
#                 'time': {'integerValue': '1567983600'},
#                 'uvIndex': {'integerValue': '3'},
#                 'sunriseTime': {'integerValue': '1568006686'},
#                 'temperatureMinTime': {'integerValue': '1567990800'},
#                 'apparentTemperatureLowTime': {'integerValue': '1568091600'},
#                 'precipIntensityMax': {'doubleValue': 0.0201},
#                 'precipIntensityMaxTime': {'integerValue': '1568030400'},
#                 'pressure': {'doubleValue': 1013.68},
#                 'windGust': {'doubleValue': 22.13},
#                 'moonPhase': {'doubleValue': 0.37},
#                 'apparentTemperatureMax': {'doubleValue': 61.21},
#                 'temperatureLowTime': {'integerValue': '1568091600'},
#                 'summary': {'stringValue': 'Light rain starting in the afternoon.'},
#                 'visibility': {'doubleValue': 9.842},
#                 'dewPoint': {'doubleValue': 46.26},
#                 'apparentTemperatureHighTime': {'integerValue': '1568034000'},
#                 'apparentTemperatureMinTime': {'integerValue': '1567994400'},
#                 'humidity': {'doubleValue': 0.76},
#                 'windBearing': {'integerValue': '184'},
#                 'cloudCover': {'doubleValue': 0.89},
#                 'apparentTemperatureMaxTime': {'integerValue': '1568034000'},
#                 'temperatureHigh': {'doubleValue': 61.21},
#                 'apparentTemperatureHigh': {'doubleValue': 61.21},
#                 'precipType': {'stringValue': 'rain'},
#                 'temperatureMaxTime': {'integerValue': '1568034000'},
#                 'temperatureMin': {'doubleValue': 46.32},
#                 'precipIntensity': {'doubleValue': 0.0061},
#                 'windSpeed': {'doubleValue': 7.3},
#                 'windGustTime': {'integerValue': '1568034000'},
#                 'temperatureHighTime': {'integerValue': '1568034000'},
#                 'icon': {'stringValue': 'rain'},
#                 'ozone': {'doubleValue': 310.5}}}},
#              {'mapValue': {'fields': {'temperatureMinTime': {'integerValue': '1568091600'},
#                 'summary': {'stringValue': 'Possible drizzle in the morning.'},
#                 'temperatureLowTime': {'integerValue': '1568160000'},
#                 'dewPoint': {'doubleValue': 51.07},
#                 'precipIntensityMaxTime': {'integerValue': '1568084400'},
#                 'precipProbability': {'doubleValue': 0.52},
#                 'apparentTemperatureLow': {'doubleValue': 53.26},
#                 'icon': {'stringValue': 'rain'},
#                 'sunriseTime': {'integerValue': '1568093181'},
#                 'ozone': {'doubleValue': 301.8},
#                 'windGust': {'doubleValue': 12.76},
#                 'windGustTime': {'integerValue': '1568156400'},
#                 'uvIndex': {'integerValue': '4'},
#                 'temperatureMax': {'doubleValue': 64.12},
#                 'apparentTemperatureMaxTime': {'integerValue': '1568124000'},
#                 'sunsetTime': {'integerValue': '1568140046'},
#                 'windSpeed': {'doubleValue': 4.31},
#                 'apparentTemperatureHighTime': {'integerValue': '1568124000'},
#                 'moonPhase': {'doubleValue': 0.4},
#                 'precipIntensity': {'doubleValue': 0.0016},
#                 'time': {'integerValue': '1568070000'},
#                 'temperatureHigh': {'doubleValue': 64.12},
#                 'visibility': {'integerValue': '10'},
#                 'temperatureMaxTime': {'integerValue': '1568124000'},
#                 'apparentTemperatureMax': {'doubleValue': 64.12},
#                 'apparentTemperatureMinTime': {'integerValue': '1568091600'},
#                 'temperatureMin': {'doubleValue': 50.65},
#                 'cloudCover': {'doubleValue': 0.73},
#                 'temperatureLow': {'doubleValue': 53.26},
#                 'apparentTemperatureMin': {'doubleValue': 50.65},
#                 'apparentTemperatureHigh': {'doubleValue': 64.12},
#                 'temperatureHighTime': {'integerValue': '1568124000'},
#                 'apparentTemperatureLowTime': {'integerValue': '1568160000'},
#                 'pressure': {'doubleValue': 1016.19},
#                 'uvIndexTime': {'integerValue': '1568116800'},
#                 'precipIntensityMax': {'doubleValue': 0.0063},
#                 'humidity': {'doubleValue': 0.8},
#                 'precipType': {'stringValue': 'rain'},
#                 'windBearing': {'integerValue': '354'}}}},
#              {'mapValue': {'fields': {'windGust': {'doubleValue': 28.59},
#                 'temperatureMaxTime': {'integerValue': '1568214000'},
#                 'precipType': {'stringValue': 'rain'},
#                 'precipIntensityMaxTime': {'integerValue': '1568185200'},
#                 'uvIndex': {'integerValue': '3'},
#                 'dewPoint': {'doubleValue': 53.44},
#                 'temperatureMax': {'doubleValue': 69.01},
#                 'moonPhase': {'doubleValue': 0.43},
#                 'apparentTemperatureMaxTime': {'integerValue': '1568214000'},
#                 'windBearing': {'integerValue': '249'},
#                 'apparentTemperatureLowTime': {'integerValue': '1568260800'},
#                 'ozone': {'doubleValue': 278.4},
#                 'temperatureHigh': {'doubleValue': 69.01},
#                 'apparentTemperatureHighTime': {'integerValue': '1568214000'},
#                 'apparentTemperatureLow': {'doubleValue': 47.49},
#                 'precipIntensity': {'doubleValue': 0.0027},
#                 'apparentTemperatureMax': {'doubleValue': 69.01},
#                 'sunriseTime': {'integerValue': '1568179676'},
#                 'apparentTemperatureMinTime': {'integerValue': '1568160000'},
#                 'temperatureLow': {'doubleValue': 49.56},
#                 'time': {'integerValue': '1568156400'},
#                 'pressure': {'doubleValue': 1018.61},
#                 'windSpeed': {'doubleValue': 9.96},
#                 'cloudCover': {'doubleValue': 0.96},
#                 'precipProbability': {'doubleValue': 0.58},
#                 'temperatureMin': {'doubleValue': 53.26},
#                 'summary': {'stringValue': 'Possible drizzle in the morning and afternoon.'},
#                 'icon': {'stringValue': 'rain'},
#                 'apparentTemperatureMin': {'doubleValue': 53.26},
#                 'uvIndexTime': {'integerValue': '1568203200'},
#                 'visibility': {'integerValue': '10'},
#                 'sunsetTime': {'integerValue': '1568226308'},
#                 'precipIntensityMax': {'doubleValue': 0.0081},
#                 'humidity': {'doubleValue': 0.81},
#                 'temperatureHighTime': {'integerValue': '1568214000'},
#                 'apparentTemperatureHigh': {'doubleValue': 69.01},
#                 'temperatureMinTime': {'integerValue': '1568160000'},
#                 'temperatureLowTime': {'integerValue': '1568257200'},
#                 'windGustTime': {'integerValue': '1568192400'}}}},
#              {'mapValue': {'fields': {'windSpeed': {'doubleValue': 9.45},
#                 'temperatureHighTime': {'integerValue': '1568293200'},
#                 'precipProbability': {'doubleValue': 0.04},
#                 'dewPoint': {'doubleValue': 53.55},
#                 'uvIndex': {'integerValue': '4'},
#                 'cloudCover': {'doubleValue': 0.71},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'apparentTemperatureMin': {'doubleValue': 47.49},
#                 'apparentTemperatureLowTime': {'integerValue': '1568350800'},
#                 'precipIntensity': {'doubleValue': 0.0002},
#                 'apparentTemperatureLow': {'doubleValue': 54.85},
#                 'apparentTemperatureMax': {'doubleValue': 74.12},
#                 'temperatureMin': {'doubleValue': 49.56},
#                 'temperatureMax': {'doubleValue': 74.12},
#                 'temperatureLow': {'doubleValue': 54.85},
#                 'pressure': {'doubleValue': 1024.78},
#                 'windGust': {'doubleValue': 25.8},
#                 'temperatureMaxTime': {'integerValue': '1568293200'},
#                 'windBearing': {'integerValue': '238'},
#                 'precipType': {'stringValue': 'rain'},
#                 'temperatureHigh': {'doubleValue': 74.12},
#                 'ozone': {'doubleValue': 273.9},
#                 'temperatureMinTime': {'integerValue': '1568257200'},
#                 'precipIntensityMaxTime': {'integerValue': '1568329200'},
#                 'temperatureLowTime': {'integerValue': '1568350800'},
#                 'moonPhase': {'doubleValue': 0.46},
#                 'humidity': {'doubleValue': 0.75},
#                 'apparentTemperatureHighTime': {'integerValue': '1568293200'},
#                 'visibility': {'integerValue': '10'},
#                 'sunriseTime': {'integerValue': '1568266171'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1568293200'},
#                 'apparentTemperatureMinTime': {'integerValue': '1568260800'},
#                 'sunsetTime': {'integerValue': '1568312569'},
#                 'time': {'integerValue': '1568242800'},
#                 'uvIndexTime': {'integerValue': '1568289600'},
#                 'apparentTemperatureHigh': {'doubleValue': 74.12},
#                 'summary': {'stringValue': 'Mostly cloudy throughout the day.'},
#                 'windGustTime': {'integerValue': '1568289600'},
#                 'precipIntensityMax': {'doubleValue': 0.0013}}}},
#              {'mapValue': {'fields': {'pressure': {'doubleValue': 1029.71},
#                 'temperatureMax': {'doubleValue': 71.94},
#                 'apparentTemperatureLow': {'integerValue': '52'},
#                 'temperatureMinTime': {'integerValue': '1568350800'},
#                 'uvIndexTime': {'integerValue': '1568376000'},
#                 'summary': {'stringValue': 'Mostly cloudy throughout the day.'},
#                 'apparentTemperatureMin': {'doubleValue': 54.85},
#                 'precipIntensity': {'doubleValue': 0.0004},
#                 'apparentTemperatureMax': {'doubleValue': 71.94},
#                 'temperatureHigh': {'doubleValue': 71.94},
#                 'windSpeed': {'doubleValue': 5.32},
#                 'ozone': {'doubleValue': 279.5},
#                 'precipType': {'stringValue': 'rain'},
#                 'temperatureMaxTime': {'integerValue': '1568383200'},
#                 'sunriseTime': {'integerValue': '1568352667'},
#                 'time': {'integerValue': '1568329200'},
#                 'windBearing': {'integerValue': '352'},
#                 'apparentTemperatureMinTime': {'integerValue': '1568350800'},
#                 'precipIntensityMax': {'doubleValue': 0.0023},
#                 'icon': {'stringValue': 'partly-cloudy-day'},
#                 'humidity': {'doubleValue': 0.73},
#                 'cloudCover': {'doubleValue': 0.61},
#                 'apparentTemperatureHighTime': {'integerValue': '1568383200'},
#                 'apparentTemperatureHigh': {'doubleValue': 71.94},
#                 'temperatureMin': {'doubleValue': 54.85},
#                 'apparentTemperatureLowTime': {'integerValue': '1568437200'},
#                 'precipIntensityMaxTime': {'integerValue': '1568332800'},
#                 'sunsetTime': {'integerValue': '1568398830'},
#                 'temperatureLow': {'integerValue': '52'},
#                 'moonPhase': {'doubleValue': 0.49},
#                 'visibility': {'integerValue': '10'},
#                 'dewPoint': {'doubleValue': 52.65},
#                 'uvIndex': {'integerValue': '4'},
#                 'windGustTime': {'integerValue': '1568329200'},
#                 'precipProbability': {'doubleValue': 0.05},
#                 'windGust': {'doubleValue': 12.46},
#                 'temperatureLowTime': {'integerValue': '1568437200'},
#                 'temperatureHighTime': {'integerValue': '1568383200'},
#                 'apparentTemperatureMaxTime': {'integerValue': '1568383200'}}}},
#              {'mapValue': {'fields': {'apparentTemperatureLow': {'doubleValue': 45.03},
#                 'apparentTemperatureHigh': {'doubleValue': 67.67},
#                 'visibility': {'integerValue': '10'},
#                 'precipProbability': {'doubleValue': 0.05},
#                 'windBearing': {'integerValue': '40'},
#                 'icon': {'stringValue': 'clear-day'},
#                 'precipIntensityMax': {'doubleValue': 0.0003},
#                 'temperatureLowTime': {'integerValue': '1568523600'},
#                 'sunsetTime': {'integerValue': '1568485091'},
#                 'windGustTime': {'integerValue': '1568494800'},
#                 'temperatureMin': {'integerValue': '52'},
#                 'time': {'integerValue': '1568415600'},
#                 'apparentTemperatureLowTime': {'integerValue': '1568523600'},
#                 'precipIntensityMaxTime': {'integerValue': '1568422800'},
#                 'precipType': {'stringValue': 'rain'},
#                 'moonPhase': {'doubleValue': 0.52},
#                 'apparentTemperatureMin': {'integerValue': '52'},
#                 'cloudCover': {'doubleValue': 0.34},
#                 'pressure': {'doubleValue': 1035.07},
#                 'temperatureLow': {'doubleValue': 48.15},
#                 'temperatureHigh': {'doubleValue': 67.67},
#                 'temperatureMax': {'doubleValue': 67.67},
#                 'dewPoint': {'doubleValue': 47.77},
#                 'temperatureMaxTime': {'integerValue': '1568469600'},
#                 'precipIntensity': {'doubleValue': 0.0001},
#                 'apparentTemperatureMaxTime': {'integerValue': '1568469600'},
#                 'windSpeed': {'doubleValue': 8.2},
#                 'humidity': {'doubleValue': 0.69},
#                 'windGust': {'doubleValue': 16.35},
#                 'uvIndexTime': {'integerValue': '1568462400'},
#                 'apparentTemperatureMax': {'doubleValue': 67.67},
#                 'sunriseTime': {'integerValue': '1568439162'},
#                 'uvIndex': {'integerValue': '5'},
#                 'summary': {'stringValue': 'Partly cloudy throughout the day.'},
#                 'ozone': {'doubleValue': 285.1},
#                 'apparentTemperatureHighTime': {'integerValue': '1568469600'},
#                 'temperatureHighTime': {'integerValue': '1568469600'},
#                 'apparentTemperatureMinTime': {'integerValue': '1568437200'},
#                 'temperatureMinTime': {'integerValue': '1568437200'}}}}]}},
#           'summary': {'stringValue': 'Light rain on Monday through Wednesday, with high temperatures bottoming out at 61°F on Monday.'},
#           'icon': {'stringValue': 'rain'}}}}}}},
#     'timestamp': {'integerValue': '1567854528635'}},
#    'createTime': '2019-09-07T11:11:02.114543Z',
#    'updateTime': '2019-09-07T11:11:02.114543Z'}],
#  'nextPageToken': 'AFTOeJwMa8psCWNCHddqBX07A2RD1drCrV3oA-RhCaIMLjlxH2cvF15FFb8UgLFgVO4lURVJlemOkNBTnO1uzUKWjWE9dtKLWxyJqOdfpHBLuzWtMGZjji8rBeUgQApNNIbanng'}

# %%
device_data
# Out:
# [{'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/00ebE6UhN4wVIJeMU8Az',
#   'fields': {'status': {'mapValue': {'fields': {'Battery_Percent': {'integerValue': '-6'},
#       'Sensors_Status': {'integerValue': '1'},
#       'MicroSD_Status': {'integerValue': '1'},
#       'WiFi_Signal': {'integerValue': '-59'},
#       'Server_Status': {'integerValue': '1'},
#       'Date': {'stringValue': '2020-05-31'},
#       'Time': {'stringValue': '15:30:44'},
#       'WiFI_Status': {'integerValue': '1'},
#       'Battery_Status': {'integerValue': '0'}}}},
#    'timestamp': {'integerValue': '1590931847726'},
#    'userInfo': {'mapValue': {'fields': {'userId': {'stringValue': 'Desk Top'},
#       'macAddress': {'stringValue': '24:6F:28:B1:DC:D8'},
#       'deviceId': {'stringValue': 'P4006'},
#       'version': {'stringValue': 'P2004.11C'},
#       'userName': {'stringValue': 'Lloyd'},
#       'ipAddress': {'stringValue': '62.203.6.17'}}}},
#    'data': {'mapValue': {'fields': {'Bearing(Compass)': {'integerValue': '135'},
#       'Pressure(BMP280)': {'doubleValue': 969.3142},
#       'Temperature(bmp280)': {'doubleValue': 26.12},
#       'VOC(CCS811)': {'integerValue': '194'},
#       'Humidity(SHT31_H)': {'doubleValue': 24.85},
#       'UVIndex(VEML6075)': {'doubleValue': 0.057497},
#       'eCO2(CCS811)': {'integerValue': '1533'},
#       'Luminance(VEML6030)': {'integerValue': '1377'},
#       'Humidity(SHT31_L)': {'doubleValue': 24.97},
#       'UVB(VEML6075)': {'doubleValue': 31.85},
#       'Altitude(BMP280)': {'doubleValue': 969.3142},
#       'Temperature(SHT31_L)': {'doubleValue': 24.82},
#       'UVA(VEML6075)': {'doubleValue': 67.67},
#       'Temperature(SHT31_H)': {'doubleValue': 24.66}}}}},
#   'createTime': '2020-05-31T13:30:47.840863Z',
#   'updateTime': '2020-05-31T13:30:47.840863Z'},
#  {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/04RJS7GERbCg6YzZqF2Q',
#   'fields': {'userInfo': {'mapValue': {'fields': {'version': {'stringValue': 'P2004.11C'},
#       'userId': {'stringValue': 'Desk Top'},
#       'macAddress': {'stringValue': '24:6F:28:B1:DC:D8'},
#       'ipAddress': {'stringValue': '62.203.6.17'},
#       'deviceId': {'stringValue': 'P4006'},
#       'userName': {'stringValue': 'Lloyd'}}}},
#    'data': {'mapValue': {'fields': {'Temperature(SHT31_L)': {'doubleValue': 24.89},
#       'Temperature(bmp280)': {'doubleValue': 26.23},
#       'UVIndex(VEML6075)': {'doubleValue': 0.040346},
#       'Pressure(BMP280)': {'doubleValue': 982.4601},
#       'Temperature(SHT31_H)': {'doubleValue': 24.8},
#       'Luminance(VEML6030)': {'integerValue': '693'},
#       'UVA(VEML6075)': {'doubleValue': 43.49},
#       'Bearing(Compass)': {'integerValue': '90'},
#       'VOC(CCS811)': {'integerValue': '588'},
#       'Humidity(SHT31_H)': {'doubleValue': 35.48},
#       'UVB(VEML6075)': {'doubleValue': 25.9},
#       'Humidity(SHT31_L)': {'doubleValue': 35.84},
#       'eCO2(CCS811)': {'integerValue': '1902'},
#       'Altitude(BMP280)': {'doubleValue': 982.4601}}}},
#    'timestamp': {'integerValue': '1590568246459'},
#    'status': {'mapValue': {'fields': {'Time': {'stringValue': '10:30:42'},
#       'Battery_Status': {'integerValue': '2'},
#       'WiFi_Signal': {'integerValue': '-63'},
#       'Server_Status': {'integerValue': '1'},
#       'MicroSD_Status': {'integerValue': '1'},
#       'Battery_Percent': {'integerValue': '92'},
#       'Date': {'stringValue': '2020-05-27'},
#       'WiFI_Status': {'integerValue': '1'},
#       'Sensors_Status': {'integerValue': '1'}}}}},
#   'createTime': '2020-05-27T08:30:46.607679Z',
#   'updateTime': '2020-05-27T08:30:46.607679Z'}]

# %%
# Now have device data in a list - find the most recent 
from datetime import datetime as dt

ts = [dt.strptime(d['createTime'][:19], "%Y-%m-%dT%H:%M:%S") for d in device_data]  # 2020-05-27T08:30:46.607679Z

# Currently just reading one datapoint although I think it would be good to use an
# average depending on the frequency of the reads.

read_data = device_data[ts.index(min(ts))]

# %%
read_data
# Out:
# {'name': 'projects/mimirhome-app/databases/(default)/documents/sensorData/04RJS7GERbCg6YzZqF2Q',
#  'fields': {'userInfo': {'mapValue': {'fields': {'version': {'stringValue': 'P2004.11C'},
#      'userId': {'stringValue': 'Desk Top'},
#      'macAddress': {'stringValue': '24:6F:28:B1:DC:D8'},
#      'ipAddress': {'stringValue': '62.203.6.17'},
#      'deviceId': {'stringValue': 'P4006'},
#      'userName': {'stringValue': 'Lloyd'}}}},
#   'data': {'mapValue': {'fields': {'Temperature(SHT31_L)': {'doubleValue': 24.89},
#      'Temperature(bmp280)': {'doubleValue': 26.23},
#      'UVIndex(VEML6075)': {'doubleValue': 0.040346},
#      'Pressure(BMP280)': {'doubleValue': 982.4601},
#      'Temperature(SHT31_H)': {'doubleValue': 24.8},
#      'Luminance(VEML6030)': {'integerValue': '693'},
#      'UVA(VEML6075)': {'doubleValue': 43.49},
#      'Bearing(Compass)': {'integerValue': '90'},
#      'VOC(CCS811)': {'integerValue': '588'},
#      'Humidity(SHT31_H)': {'doubleValue': 35.48},
#      'UVB(VEML6075)': {'doubleValue': 25.9},
#      'Humidity(SHT31_L)': {'doubleValue': 35.84},
#      'eCO2(CCS811)': {'integerValue': '1902'},
#      'Altitude(BMP280)': {'doubleValue': 982.4601}}}},
#   'timestamp': {'integerValue': '1590568246459'},
#   'status': {'mapValue': {'fields': {'Time': {'stringValue': '10:30:42'},
#      'Battery_Status': {'integerValue': '2'},
#      'WiFi_Signal': {'integerValue': '-63'},
#      'Server_Status': {'integerValue': '1'},
#      'MicroSD_Status': {'integerValue': '1'},
#      'Battery_Percent': {'integerValue': '92'},
#      'Date': {'stringValue': '2020-05-27'},
#      'WiFI_Status': {'integerValue': '1'},
#      'Sensors_Status': {'integerValue': '1'}}}}},
#  'createTime': '2020-05-27T08:30:46.607679Z',
#  'updateTime': '2020-05-27T08:30:46.607679Z'}

# %% [markdown]
# ## 2. Obtain Plant Data

# %%
# Get the relevant sensor data
plant_data = requests.get(base_url + "plants/" + plant_species).text
plant_json = json.loads(plant_data)
plant_json
# Out:
# {'name': 'projects/mimirhome-app/databases/(default)/documents/plants/aloe vera',
#  'fields': {'basic': {'mapValue': {'fields': {'color': {'stringValue': 'Leaf color green'},
#      'category': {'stringValue': 'Liliaceae, Aloe'},
#      'origin': {'stringValue': 'Africa'},
#      'blooming': {'stringValue': 'Succulent plants, sometimes flowers, yellow or orange flowers'},
#      'floral_language': {'stringValue': 'Aloe vera\nFloriography: self-respect, tenacious, vital.\nAloe vera is a compact evergreen succulent plant. Leaves thick and juicy, long lanceolate shaped with spines at edges. Besides ornamental cultivation, A. vera is popular for anti-bacteria, anti-inflammation, facial and mosquito off.\nAloe vera requires sunbath for growth. It would go into short dormancy in winter and should stay warm. Yellow or orange flowers bloom in spring and summer.'},
#      'production': {'stringValue': 'China'}}}},
#   'image': {'stringValue': 'http://pkb.resource.huahuacaocao.com/YWxvZSB2ZXJhLmpwZw==?imageView2/1/w/%d/h/%d'},
#   'pid': {'stringValue': 'aloe vera'},
#   'display_pid': {'stringValue': 'Aloe vera'},
#   'maintenance': {'mapValue': {'fields': {'pruning': {'stringValue': 'Remove dead and rotten part timely'},
#      'watering': {'stringValue': 'Need a lot of water when in peak growth stages during April to May, reduce water in summer and winter'},
#      'sunlight': {'stringValue': 'Like sunshine, resistant to half shade, avoid strong direct light at noon in summer, excessive growth with less light'},
#      'fertilization': {'stringValue': 'Apply liquid fertilizers during April to May and September to November, except in summer and winter'},
#      'soil': {'stringValue': 'Peat mixed with coarse sand soil'},
#      'size': {'stringValue': 'Diameter ≥ 10 cm, height ≥ 15 cm'}}}},
#   'parameter': {'mapValue': {'fields': {'max_temp': {'integerValue': '35'},
#      'max_env_humid': {'integerValue': '80'},
#      'min_temp': {'integerValue': '8'},
#      'min_soil_moist': {'integerValue': '7'},
#      'max_soil_ec': {'integerValue': '1000'},
#      'min_soil_ec': {'integerValue': '300'},
#      'max_light_mmol': {'integerValue': '6400'},
#      'max_soil_moist': {'integerValue': '50'},
#      'max_light_lux': {'integerValue': '70000'},
#      'min_light_lux': {'integerValue': '3000'},
#      'min_light_mmol': {'integerValue': '3200'},
#      'min_env_humid': {'integerValue': '15'}}}}},
#  'createTime': '2020-03-22T19:24:49.399303Z',
#  'updateTime': '2020-03-22T19:24:49.399303Z'}

# %% [markdown]
# ## 3. Perform Analysis

# %%
import numpy
import skfuzzy as fuzz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-27af4b924c79> in <module>
#       1 import numpy
# ----> 2 import skfuzzy as fuzz
#
# ModuleNotFoundError: No module named 'skfuzzy'

# %%
ideal_dict = plant_json['fields']['parameter']['mapValue']['fields']
actual_dict = read_data['fields']['data']['mapValue']['fields']
print('Ideal Ranges: \n')
pprint(ideal_dict)
print('Actual Readings : \n')
pprint(actual_dict)
# Out:
# Ideal Ranges:
#
# {'max_env_humid': {'integerValue': '80'},
#  'max_light_lux': {'integerValue': '70000'},
#  'max_light_mmol': {'integerValue': '6400'},
#  'max_soil_ec': {'integerValue': '1000'},
#  'max_soil_moist': {'integerValue': '50'},
#  'max_temp': {'integerValue': '35'},
#  'min_env_humid': {'integerValue': '15'},
#  'min_light_lux': {'integerValue': '3000'},
#  'min_light_mmol': {'integerValue': '3200'},
#  'min_soil_ec': {'integerValue': '300'},
#  'min_soil_moist': {'integerValue': '7'},
#  'min_temp': {'integerValue': '8'}}
# Actual Readings :
#
# {'Altitude(BMP280)': {'doubleValue': 982.4601},
#  'Bearing(Compass)': {'integerValue': '90'},
#  'Humidity(SHT31_H)': {'doubleValue': 35.48},
#  'Humidity(SHT31_L)': {'doubleValue': 35.84},
#  'Luminance(VEML6030)': {'integerValue': '693'},
#  'Pressure(BMP280)': {'doubleValue': 982.4601},
#  'Temperature(SHT31_H)': {'doubleValue': 24.8},
#  'Temperature(SHT31_L)': {'doubleValue': 24.89},
#  'Temperature(bmp280)': {'doubleValue': 26.23},
#  'UVA(VEML6075)': {'doubleValue': 43.49},
#  'UVB(VEML6075)': {'doubleValue': 25.9},
#  'UVIndex(VEML6075)': {'doubleValue': 0.040346},
#  'VOC(CCS811)': {'integerValue': '588'},
#  'eCO2(CCS811)': {'integerValue': '1902'}}

# %%
class EnvironmentalAnalysis():
    
    # Imports
    import numpy as np
    
    def __init__(self, species):
        
        self.species = species # plant species
    
    @staticmethod
    def rangeFunc(min, max, val):
        """
        Class method to look at a value compared to its ideal range.

        Args:
            min (float): minimum value in the range.
            max (float): maximum value in the range.
            val (float): recorded value

        Returns:
            position (float): relative position between the extremes.

        """
        # Get the relative postion of the value between the extremes
        # If it is at the max then it will be 1
        # If it is at the min then it will be 0
        postion = (val - min)/(max - min)
        return postion
             
        
    def radarMode(self, ideal, actual):
        """
        Class method to perform Radar Analysis mode

        Args:
            ideal (dict): Dictionary containing all the ideal conditions for the given species.
            actual (dict): Sensor Readings for the actual environmental conditons.

        Returns:   
            result (dict): Dictionary containing the results of the radar analysis

        """
    
        # Create the extreme dictionary (sounds extreme)
        extreme_dict = {}
        extreme_dict['humidity'] = (int(ideal['min_env_humid']['integerValue']), int(ideal['max_env_humid']['integerValue']))
        extreme_dict['temperature'] = (int(ideal['min_temp']['integerValue']), int(ideal['max_temp']['integerValue']))
        extreme_dict['light'] = (int(ideal['min_light_lux']['integerValue']), int(ideal['max_light_lux']['integerValue']))
        
        print(extreme_dict)

        # Create dictionary containing actual readings
        reading_dict = {}
        reading_dict['humidity'] = self.np.mean([actual['Humidity(SHT31_H)']['doubleValue'], actual['Humidity(SHT31_L)']['doubleValue']])
        reading_dict['temperature']  = self.np.mean([actual['Temperature(SHT31_H)']['doubleValue'], actual['Temperature(SHT31_L)']['doubleValue']])
        reading_dict['light'] = int(actual['Luminance(VEML6030)']['integerValue'])
        
        print(reading_dict)

        # Get Results 
        result_dict = {}
        for condition in ['humidity', 'temperature', 'light']:
            result_dict[condition] = self.rangeFunc(extreme_dict[condition][0], extreme_dict[condition][1], reading_dict[condition])

        return result_dict
    
    def natlangFeedback(self, result_dict):
        """
        Class method to provide some natural language feedback given results
        
        Args:
            result_dict (dict): Dictionary of results from an analysis mode.
            
        """
       
        for k, v in result_dict.items():
            if v <= 0:
                print(f"The {k} is dangerously low for {self.species}.")
            elif v > 0 and v <= 0.25:
                print(f"The {k} is very low for {self.species}.")
            elif v > 0.25 and v <= 0.75:
                print(f"The {k} is a good level for {self.species}.")
            elif v > 0.75 and v <= 1:
                print(f"The {k} is a very high for {self.species}.")
            else:
                print(f"The {k} is a dangerously high for {self.species}.")

# %%
# Initialise a class
analysis = EnvironmentalAnalysis(plant_species)
results = analysis.radarMode(ideal_dict, actual_dict)
print(results)
# Out:
# {'humidity': (15, 80), 'temperature': (8, 35), 'light': (3000, 70000)}
# {'humidity': 35.66, 'temperature': 24.845, 'light': 693}
# {'humidity': 0.3178461538461538, 'temperature': 0.6238888888888888, 'light': -0.03443283582089552}

# %%
analysis.natlangFeedback(results)
# Out:
# The humidity is a good level for aloe vera.
# The temperature is a good level for aloe vera.
# The light is dangerously low for aloe vera.
